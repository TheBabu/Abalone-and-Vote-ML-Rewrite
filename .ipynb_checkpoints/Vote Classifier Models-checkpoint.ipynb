# %% [markdown]
# ### Import Libraries

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import math
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.

# %% [markdown]
# ### Load Data

# %%
dataframe = pd.read_csv("vote.csv")
dataframe.replace(np.NaN, "u", inplace=True) #Replace NaN with "u" (Unknown)
dataframe = pd.get_dummies(dataframe, columns=["Class"], prefix="party") #One hot encode "Class" label
dataframe
# Out:
#     handicapped-infants water-project-cost-sharing  \
# 0                     n                          y
# 1                     n                          y
# 2                     u                          y
# 3                     n                          y
# 4                     y                          y
# ..                  ...                        ...
# 430                   n                          n
# 431                   n                          n
# 432                   n                          u
# 433                   n                          n
# 434                   n                          y
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                   n                    y               y
# 1                                   n                    y               y
# 2                                   y                    u               y
# 3                                   y                    n               u
# 4                                   y                    n               y
# ..                                ...                  ...             ...
# 430                                 y                    y               y
# 431                                 y                    n               n
# 432                                 n                    y               y
# 433                                 n                    y               y
# 434                                 n                    y               y
#
#     religious-groups-in-schools anti-satellite-test-ban  \
# 0                             y                       n
# 1                             y                       n
# 2                             y                       n
# 3                             y                       n
# 4                             y                       n
# ..                          ...                     ...
# 430                           y                       n
# 431                           n                       y
# 432                           y                       n
# 433                           y                       u
# 434                           y                       n
#
#     aid-to-nicaraguan-contras mx-missile immigration  \
# 0                           n          n           y
# 1                           n          n           n
# 2                           n          n           n
# 3                           n          n           n
# 4                           n          n           n
# ..                        ...        ...         ...
# 430                         n          y           y
# 431                         y          y           y
# 432                         n          n           n
# 433                         u          u           u
# 434                         n          n           y
#
#     synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                              u                  y                      y
# 1                              n                  y                      y
# 2                              y                  n                      y
# 3                              y                  n                      y
# 4                              y                  u                      y
# ..                           ...                ...                    ...
# 430                            n                  y                      y
# 431                            n                  n                      n
# 432                            y                  y                      y
# 433                            n                  y                      y
# 434                            n                  y                      y
#
#     crime duty-free-exports export-administration-act-south-africa  \
# 0       y                 n                                      y
# 1       y                 n                                      u
# 2       y                 n                                      n
# 3       n                 n                                      y
# 4       y                 y                                      y
# ..    ...               ...                                    ...
# 430     y                 n                                      y
# 431     n                 n                                      y
# 432     y                 n                                      y
# 433     y                 n                                      y
# 434     y                 u                                      n
#
#      party_democrat  party_republican
# 0                 0                 1
# 1                 0                 1
# 2                 1                 0
# 3                 1                 0
# 4                 1                 0
# ..              ...               ...
# 430               0                 1
# 431               1                 0
# 432               0                 1
# 433               0                 1
# 434               0                 1
#
# [435 rows x 18 columns]

# %%
#Convert Dataframe to Dataset
def df_to_ds(dataframe, selected_features, selected_targets, batch_size=32):
    features = dataframe[selected_features]
    targets = dataframe[selected_targets]
    ds = tf.data.Dataset.from_tensor_slices((dict(features), np.array(targets)))
    ds = ds.batch(batch_size)
    return ds

# %%
#Selected Features and Target
selected_features = [
    "handicapped-infants",
    "water-project-cost-sharing",
    "adoption-of-the-budget-resolution",
    "physician-fee-freeze",
    "el-salvador-aid",
    "religious-groups-in-schools",
    "anti-satellite-test-ban",
    "aid-to-nicaraguan-contras",
    "mx-missile",
    "immigration",
    "synfuels-corporation-cutback",
    "education-spending",
    "superfund-right-to-sue",
    "crime",
    "duty-free-exports",
    "export-administration-act-south-africa"]

selected_targets = ["party_republican", "party_democrat"]

#Feature Columns
vote_vocab_list = ["y", "n", "u"]

feature_columns = []
for f in selected_features:
    feature_columns.append(tf.feature_column.indicator_column(tf.feature_column.categorical_column_with_vocabulary_list(f, vote_vocab_list)),)

#Create Tensorflow Datasets
train_per = 0.6
validation_per = 0.3
test_per = 0.1
batch_size = 20

train_dataframe, test_dataframe = train_test_split(dataframe, test_size=test_per)
train_dataframe, validation_dataframe = train_test_split(train_dataframe, test_size=validation_per / (1 - test_per))

train_dataset = df_to_ds(
    train_dataframe,
    selected_features,
    selected_targets,
    batch_size=batch_size)
validation_dataset = df_to_ds(
    validation_dataframe,
    selected_features,
    selected_targets,
    batch_size=batch_size)
test_dataset = df_to_ds(
    test_dataframe,
    selected_features,
    selected_targets,
    batch_size=batch_size)

# %% [markdown]
# ### Create Models

# %%
linear_model = tf.keras.models.Sequential([
    tf.keras.layers.DenseFeatures(feature_columns),
    tf.keras.layers.Dense(2, kernel_regularizer=tf.keras.regularizers.l2(0.05), bias_regularizer=tf.keras.regularizers.l2(0.05)),
])

linear_model.compile(
    optimizer="adam",
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"])

# %%
nn_model = tf.keras.models.Sequential([
    tf.keras.layers.DenseFeatures(feature_columns),
    tf.keras.layers.Dense(10, activation=tf.nn.leaky_relu, kernel_regularizer=tf.keras.regularizers.l2(0.01), bias_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(5, activation=tf.nn.leaky_relu, kernel_regularizer=tf.keras.regularizers.l2(0.01), bias_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(2),
])

nn_model.compile(
    optimizer="adam",
    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"])

# %% [markdown]
# ### Train Models

# %%
def plot_loss(model):
    plt.ylabel("Loss")
    plt.xlabel("Epochs")
    plt.tight_layout()
    plt.plot(model.history.history["loss"], label="loss")
    if("val_loss" in model.history.history.keys()):
        plt.plot(model.history.history["val_loss"], label="val_loss")
    plt.legend()
    plt.show()

# %%
def plot_accuracy(model):
    plt.ylabel("Accuracy")
    plt.xlabel("Epochs")
    plt.tight_layout()
    plt.plot(model.history.history["accuracy"], label="accuracy")
    if("val_accuracy" in model.history.history.keys()):
        plt.plot(model.history.history["val_accuracy"], label="val_accuracy")
    plt.legend()
    plt.show()

# %%
linear_model.fit(train_dataset, validation_data=validation_dataset, epochs=30, verbose=2)

plot_loss(linear_model)
plot_accuracy(linear_model)
# Out:
# Epoch 1/30
# 9/9 - 3s - loss: 1.2655 - accuracy: 0.2692 - val_loss: 1.1801 - val_accuracy: 0.3664
# Epoch 2/30
# 9/9 - 0s - loss: 1.1654 - accuracy: 0.3154 - val_loss: 1.1053 - val_accuracy: 0.4122
# Epoch 3/30
# 9/9 - 0s - loss: 1.0764 - accuracy: 0.3462 - val_loss: 1.0370 - val_accuracy: 0.4351
# Epoch 4/30
# 9/9 - 0s - loss: 0.9967 - accuracy: 0.3808 - val_loss: 0.9746 - val_accuracy: 0.4885
# Epoch 5/30
# 9/9 - 0s - loss: 0.9259 - accuracy: 0.4500 - val_loss: 0.9177 - val_accuracy: 0.5344
# Epoch 6/30
# 9/9 - 0s - loss: 0.8635 - accuracy: 0.5462 - val_loss: 0.8659 - val_accuracy: 0.6107
# Epoch 7/30
# 9/9 - 0s - loss: 0.8088 - accuracy: 0.6000 - val_loss: 0.8189 - val_accuracy: 0.6412
# Epoch 8/30
# 9/9 - 0s - loss: 0.7608 - accuracy: 0.6577 - val_loss: 0.7763 - val_accuracy: 0.7252
# Epoch 9/30
# 9/9 - 0s - loss: 0.7187 - accuracy: 0.7154 - val_loss: 0.7378 - val_accuracy: 0.7710
# Epoch 10/30
# 9/9 - 0s - loss: 0.6818 - accuracy: 0.7423 - val_loss: 0.7030 - val_accuracy: 0.8015
# Epoch 11/30
# 9/9 - 0s - loss: 0.6492 - accuracy: 0.7885 - val_loss: 0.6716 - val_accuracy: 0.8168
# Epoch 12/30
# 9/9 - 0s - loss: 0.6205 - accuracy: 0.8192 - val_loss: 0.6433 - val_accuracy: 0.8473
# Epoch 13/30
# 9/9 - 0s - loss: 0.5949 - accuracy: 0.8500 - val_loss: 0.6178 - val_accuracy: 0.8473
# Epoch 14/30
# 9/9 - 0s - loss: 0.5722 - accuracy: 0.8500 - val_loss: 0.5947 - val_accuracy: 0.8550
# Epoch 15/30
# 9/9 - 0s - loss: 0.5519 - accuracy: 0.8538 - val_loss: 0.5738 - val_accuracy: 0.8779
# Epoch 16/30
# 9/9 - 0s - loss: 0.5336 - accuracy: 0.8577 - val_loss: 0.5549 - val_accuracy: 0.8779
# Epoch 17/30
# 9/9 - 0s - loss: 0.5170 - accuracy: 0.8769 - val_loss: 0.5377 - val_accuracy: 0.8779
# Epoch 18/30
# 9/9 - 0s - loss: 0.5021 - accuracy: 0.8808 - val_loss: 0.5221 - val_accuracy: 0.8931
# Epoch 19/30
# 9/9 - 0s - loss: 0.4884 - accuracy: 0.8885 - val_loss: 0.5078 - val_accuracy: 0.8931
# Epoch 20/30
# 9/9 - 0s - loss: 0.4759 - accuracy: 0.9038 - val_loss: 0.4948 - val_accuracy: 0.9008
# Epoch 21/30
# 9/9 - 0s - loss: 0.4645 - accuracy: 0.9038 - val_loss: 0.4828 - val_accuracy: 0.9084
# Epoch 22/30
# 9/9 - 0s - loss: 0.4539 - accuracy: 0.9077 - val_loss: 0.4717 - val_accuracy: 0.9084
# Epoch 23/30
# 9/9 - 0s - loss: 0.4441 - accuracy: 0.9077 - val_loss: 0.4615 - val_accuracy: 0.9084
# Epoch 24/30
# 9/9 - 0s - loss: 0.4351 - accuracy: 0.9115 - val_loss: 0.4520 - val_accuracy: 0.9084
# Epoch 25/30
# 9/9 - 0s - loss: 0.4267 - accuracy: 0.9154 - val_loss: 0.4433 - val_accuracy: 0.9084
# Epoch 26/30
# 9/9 - 0s - loss: 0.4188 - accuracy: 0.9154 - val_loss: 0.4351 - val_accuracy: 0.9160
# Epoch 27/30
# 9/9 - 0s - loss: 0.4114 - accuracy: 0.9154 - val_loss: 0.4275 - val_accuracy: 0.9160
# Epoch 28/30
# 9/9 - 0s - loss: 0.4045 - accuracy: 0.9154 - val_loss: 0.4203 - val_accuracy: 0.9160
# Epoch 29/30
# 9/9 - 0s - loss: 0.3981 - accuracy: 0.9154 - val_loss: 0.4136 - val_accuracy: 0.9160
# Epoch 30/30
# 9/9 - 0s - loss: 0.3919 - accuracy: 0.9115 - val_loss: 0.4074 - val_accuracy: 0.9084

# %%
nn_model.fit(train_dataset, validation_data=validation_dataset, epochs=30, verbose=2)

plot_loss(nn_model)
plot_accuracy(nn_model)
# Out:
# Epoch 1/30
# 9/9 - 3s - loss: 0.6826 - accuracy: 0.7385 - val_loss: 0.7455 - val_accuracy: 0.7328
# Epoch 2/30
# 9/9 - 0s - loss: 0.6203 - accuracy: 0.8115 - val_loss: 0.6605 - val_accuracy: 0.8397
# Epoch 3/30
# 9/9 - 0s - loss: 0.5611 - accuracy: 0.8808 - val_loss: 0.5933 - val_accuracy: 0.8626
# Epoch 4/30
# 9/9 - 0s - loss: 0.5144 - accuracy: 0.8923 - val_loss: 0.5508 - val_accuracy: 0.8550
# Epoch 5/30
# 9/9 - 0s - loss: 0.4804 - accuracy: 0.9115 - val_loss: 0.5216 - val_accuracy: 0.8626
# Epoch 6/30
# 9/9 - 0s - loss: 0.4535 - accuracy: 0.9231 - val_loss: 0.4987 - val_accuracy: 0.8702
# Epoch 7/30
# 9/9 - 0s - loss: 0.4316 - accuracy: 0.9269 - val_loss: 0.4807 - val_accuracy: 0.8779
# Epoch 8/30
# 9/9 - 0s - loss: 0.4132 - accuracy: 0.9308 - val_loss: 0.4654 - val_accuracy: 0.8855
# Epoch 9/30
# 9/9 - 0s - loss: 0.3971 - accuracy: 0.9385 - val_loss: 0.4515 - val_accuracy: 0.8931
# Epoch 10/30
# 9/9 - 0s - loss: 0.3827 - accuracy: 0.9385 - val_loss: 0.4380 - val_accuracy: 0.8931
# Epoch 11/30
# 9/9 - 0s - loss: 0.3695 - accuracy: 0.9423 - val_loss: 0.4248 - val_accuracy: 0.8931
# Epoch 12/30
# 9/9 - 0s - loss: 0.3570 - accuracy: 0.9500 - val_loss: 0.4119 - val_accuracy: 0.8931
# Epoch 13/30
# 9/9 - 0s - loss: 0.3454 - accuracy: 0.9538 - val_loss: 0.4000 - val_accuracy: 0.8931
# Epoch 14/30
# 9/9 - 0s - loss: 0.3345 - accuracy: 0.9538 - val_loss: 0.3891 - val_accuracy: 0.8931
# Epoch 15/30
# 9/9 - 0s - loss: 0.3243 - accuracy: 0.9538 - val_loss: 0.3792 - val_accuracy: 0.8931
# Epoch 16/30
# 9/9 - 0s - loss: 0.3146 - accuracy: 0.9538 - val_loss: 0.3697 - val_accuracy: 0.9008
# Epoch 17/30
# 9/9 - 0s - loss: 0.3054 - accuracy: 0.9615 - val_loss: 0.3606 - val_accuracy: 0.9084
# Epoch 18/30
# 9/9 - 0s - loss: 0.2968 - accuracy: 0.9615 - val_loss: 0.3521 - val_accuracy: 0.9160
# Epoch 19/30
# 9/9 - 0s - loss: 0.2888 - accuracy: 0.9615 - val_loss: 0.3442 - val_accuracy: 0.9160
# Epoch 20/30
# 9/9 - 0s - loss: 0.2813 - accuracy: 0.9615 - val_loss: 0.3368 - val_accuracy: 0.9237
# Epoch 21/30
# 9/9 - 0s - loss: 0.2742 - accuracy: 0.9615 - val_loss: 0.3298 - val_accuracy: 0.9237
# Epoch 22/30
# 9/9 - 0s - loss: 0.2676 - accuracy: 0.9654 - val_loss: 0.3229 - val_accuracy: 0.9313
# Epoch 23/30
# 9/9 - 0s - loss: 0.2613 - accuracy: 0.9654 - val_loss: 0.3162 - val_accuracy: 0.9389
# Epoch 24/30
# 9/9 - 0s - loss: 0.2554 - accuracy: 0.9654 - val_loss: 0.3100 - val_accuracy: 0.9389
# Epoch 25/30
# 9/9 - 0s - loss: 0.2498 - accuracy: 0.9654 - val_loss: 0.3041 - val_accuracy: 0.9389
# Epoch 26/30
# 9/9 - 0s - loss: 0.2445 - accuracy: 0.9654 - val_loss: 0.2986 - val_accuracy: 0.9389
# Epoch 27/30
# 9/9 - 0s - loss: 0.2395 - accuracy: 0.9654 - val_loss: 0.2930 - val_accuracy: 0.9389
# Epoch 28/30
# 9/9 - 0s - loss: 0.2347 - accuracy: 0.9692 - val_loss: 0.2878 - val_accuracy: 0.9389
# Epoch 29/30
# 9/9 - 0s - loss: 0.2302 - accuracy: 0.9731 - val_loss: 0.2828 - val_accuracy: 0.9389
# Epoch 30/30
# 9/9 - 0s - loss: 0.2259 - accuracy: 0.9731 - val_loss: 0.2780 - val_accuracy: 0.9389

# %% [markdown]
# ### Evaluation

# %%
linear_model.evaluate(test_dataset)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4538 - accuracy: 0.8864
# [0.45376044511795044, 0.8863636255264282]

# %%
nn_model.evaluate(test_dataset)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2590 - accuracy: 0.9545
# [0.25896963477134705, 0.9545454382896423]

# %% [markdown]
# ### Predictions

# %%
labels = test_dataframe[selected_targets].reset_index(drop=True)

# %%
linear_predictions = pd.DataFrame(tf.nn.softmax(linear_model.predict(test_dataset)).numpy()).join(labels)
linear_predictions.columns = ["probability_republican", "probability_democrat", "label_republican", "label_democrat"]

linear_prediction_values = linear_predictions[list(linear_predictions.columns[0:2])].idxmax(axis=1).apply(lambda x : linear_predictions.columns.get_loc(x) + 2)
linear_label_values = linear_predictions[list(linear_predictions.columns[2:4])].idxmax(axis=1).apply(lambda x : linear_predictions.columns.get_loc(x))

linear_predictions["correct"] = linear_prediction_values.combine(linear_label_values, lambda x, y : x == y)

linear_predictions
# Out:
#     probability_republican  probability_democrat  label_republican  \
# 0                 0.047460              0.952540                 0
# 1                 0.633767              0.366233                 1
# 2                 0.468659              0.531341                 0
# 3                 0.495977              0.504023                 0
# 4                 0.144976              0.855024                 0
# 5                 0.085460              0.914540                 0
# 6                 0.062246              0.937754                 0
# 7                 0.327382              0.672618                 0
# 8                 0.292846              0.707154                 0
# 9                 0.263604              0.736396                 0
# 10                0.639490              0.360510                 0
# 11                0.041872              0.958128                 0
# 12                0.061219              0.938781                 0
# 13                0.121750              0.878250                 0
# 14                0.610436              0.389564                 1
# 15                0.102865              0.897135                 0
# 16                0.049913              0.950087                 0
# 17                0.712543              0.287457                 1
# 18                0.076941              0.923059                 0
# 19                0.048231              0.951769                 0
# 20                0.060719              0.939281                 0
# 21                0.740876              0.259124                 1
# 22                0.420106              0.579894                 0
# 23                0.832163              0.167837                 1
# 24                0.832163              0.167837                 1
# 25                0.044344              0.955656                 0
# 26                0.183104              0.816896                 0
# 27                0.085006              0.914994                 0
# 28                0.700368              0.299632                 1
# 29                0.292436              0.707564                 1
# 30                0.184151              0.815849                 1
# 31                0.522912              0.477088                 1
# 32                0.074542              0.925458                 0
# 33                0.777178              0.222822                 1
# 34                0.821118              0.178882                 1
# 35                0.107917              0.892083                 0
# 36                0.237032              0.762968                 0
# 37                0.777178              0.222822                 1
# 38                0.457056              0.542944                 0
# 39                0.043873              0.956127                 0
# 40                0.347882              0.652118                 1
# 41                0.473004              0.526996                 1
# 42                0.683944              0.316056                 1
# 43                0.828284              0.171716                 1
#
#     label_democrat  correct
# 0                1     True
# 1                0     True
# 2                1     True
# 3                1     True
# 4                1     True
# 5                1     True
# 6                1     True
# 7                1     True
# 8                1     True
# 9                1     True
# 10               1    False
# 11               1     True
# 12               1     True
# 13               1     True
# 14               0     True
# 15               1     True
# 16               1     True
# 17               0     True
# 18               1     True
# 19               1     True
# 20               1     True
# 21               0     True
# 22               1     True
# 23               0     True
# 24               0     True
# 25               1     True
# 26               1     True
# 27               1     True
# 28               0     True
# 29               0    False
# 30               0    False
# 31               0     True
# 32               1     True
# 33               0     True
# 34               0     True
# 35               1     True
# 36               1     True
# 37               0     True
# 38               1     True
# 39               1     True
# 40               0    False
# 41               0    False
# 42               0     True
# 43               0     True

# %%
nn_predictions = pd.DataFrame(tf.nn.softmax(nn_model.predict(test_dataset)).numpy()).join(labels)
nn_predictions.columns = ["probability_republican", "probability_democrat", "label_republican", "label_democrat"]

nn_prediction_values = nn_predictions[list(linear_predictions.columns[0:2])].idxmax(axis=1).apply(lambda x : nn_predictions.columns.get_loc(x) + 2)
nn_label_values = nn_predictions[list(linear_predictions.columns[2:4])].idxmax(axis=1).apply(lambda x : nn_predictions.columns.get_loc(x))

nn_predictions["correct"] = nn_prediction_values.combine(nn_label_values, lambda x, y : x == y)

nn_predictions
# Out:
#     probability_republican  probability_democrat  label_republican  \
# 0                 0.016758              0.983242                 0
# 1                 0.636124              0.363876                 1
# 2                 0.080787              0.919213                 0
# 3                 0.134513              0.865487                 0
# 4                 0.002467              0.997533                 0
# 5                 0.008977              0.991023                 0
# 6                 0.003027              0.996973                 0
# 7                 0.027369              0.972631                 0
# 8                 0.016296              0.983704                 0
# 9                 0.034416              0.965584                 0
# 10                0.200520              0.799480                 0
# 11                0.007144              0.992855                 0
# 12                0.007058              0.992942                 0
# 13                0.003008              0.996992                 0
# 14                0.676758              0.323242                 1
# 15                0.019386              0.980614                 0
# 16                0.003662              0.996338                 0
# 17                0.974310              0.025690                 1
# 18                0.003174              0.996826                 0
# 19                0.006893              0.993107                 0
# 20                0.024657              0.975343                 0
# 21                0.897197              0.102803                 1
# 22                0.352685              0.647315                 0
# 23                0.967137              0.032863                 1
# 24                0.967137              0.032863                 1
# 25                0.011765              0.988235                 0
# 26                0.022057              0.977943                 0
# 27                0.008414              0.991586                 0
# 28                0.964154              0.035846                 1
# 29                0.299458              0.700542                 1
# 30                0.738617              0.261383                 1
# 31                0.935604              0.064396                 1
# 32                0.012324              0.987676                 0
# 33                0.957892              0.042108                 1
# 34                0.959764              0.040236                 1
# 35                0.003885              0.996115                 0
# 36                0.007874              0.992126                 0
# 37                0.957892              0.042108                 1
# 38                0.557690              0.442310                 0
# 39                0.013119              0.986881                 0
# 40                0.536350              0.463650                 1
# 41                0.904557              0.095443                 1
# 42                0.955281              0.044719                 1
# 43                0.947409              0.052591                 1
#
#     label_democrat  correct
# 0                1     True
# 1                0     True
# 2                1     True
# 3                1     True
# 4                1     True
# 5                1     True
# 6                1     True
# 7                1     True
# 8                1     True
# 9                1     True
# 10               1     True
# 11               1     True
# 12               1     True
# 13               1     True
# 14               0     True
# 15               1     True
# 16               1     True
# 17               0     True
# 18               1     True
# 19               1     True
# 20               1     True
# 21               0     True
# 22               1     True
# 23               0     True
# 24               0     True
# 25               1     True
# 26               1     True
# 27               1     True
# 28               0     True
# 29               0    False
# 30               0     True
# 31               0     True
# 32               1     True
# 33               0     True
# 34               0     True
# 35               1     True
# 36               1     True
# 37               0     True
# 38               1    False
# 39               1     True
# 40               0     True
# 41               0     True
# 42               0     True
# 43               0     True

# %% [markdown]
# ### Backend

# %% [markdown]
# #### Linear

# %%
linear_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_features (DenseFeature multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  98
# =================================================================
# Total params: 98
# Trainable params: 98
# Non-trainable params: 0
# _________________________________________________________________

# %%
linear_model.history.params
# Out:
# {'verbose': 0, 'epochs': 1, 'steps': 2}

# %%
for layer in linear_model.layers:
    print(layer.get_weights())
# Out:
# []
# [array([[ 0.00234804,  0.33207235],
#        [ 0.02968898, -0.08593221],
#        [-0.03406239, -0.02437016],
#        [-0.3157841 ,  0.15461151],
#        [ 0.14360406,  0.16185127],
#        [ 0.04916715, -0.08977112],
#        [ 0.0162585 ,  0.08872534],
#        [-0.10078584,  0.16124654],
#        [ 0.02039232, -0.00838295],
#        [ 0.15661946,  0.09179708],
#        [ 0.00439412,  0.1219754 ],
#        [-0.0868132 , -0.01752543],
#        [-0.41434452, -0.06654837],
#        [-0.21853907, -0.15340054],
#        [-0.03548316,  0.11160292],
#        [ 0.13601254,  0.17337014],
#        [-0.16351424,  0.06821568],
#        [-0.04750075, -0.13941063],
#        [ 0.16322061, -0.29657307],
#        [-0.14982294,  0.00867223],
#        [ 0.00512403,  0.12559523],
#        [ 0.16510782, -0.12466653],
#        [ 0.24231815, -0.16531081],
#        [-0.23325446,  0.11110046],
#        [-0.04325456,  0.04786748],
#        [ 0.14818726,  0.08251935],
#        [-0.02755852,  0.02953134],
#        [ 0.14083089, -0.09031466],
#        [ 0.09014129,  0.16382794],
#        [ 0.02316521, -0.01864872],
#        [ 0.03131224, -0.02905215],
#        [ 0.0118202 ,  0.00727336],
#        [-0.04770661,  0.15126243],
#        [ 0.339629  , -0.02599448],
#        [-0.07360543,  0.10103257],
#        [ 0.03385478,  0.03423847],
#        [-0.01013432, -0.06856655],
#        [ 0.16569597,  0.33814785],
#        [ 0.03368257, -0.01497941],
#        [ 0.05953655, -0.26931506],
#        [-0.40601417,  0.23874065],
#        [-0.15107973, -0.0941781 ],
#        [-0.25129247, -0.12571017],
#        [-0.07814247, -0.1687153 ],
#        [ 0.00819564, -0.01541122],
#        [ 0.14226517,  0.23779035],
#        [-0.17290041, -0.15446977],
#        [ 0.03375875,  0.02341148]], dtype=float32), array([-0.09523176,  0.09523176], dtype=float32)]

# %% [markdown]
# #### Neural Network

# %%
nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_features_1 (DenseFeatu multiple                  0
# _________________________________________________________________
# dense_1 (Dense)              multiple                  490
# _________________________________________________________________
# dense_2 (Dense)              multiple                  55
# _________________________________________________________________
# dense_3 (Dense)              multiple                  12
# =================================================================
# Total params: 557
# Trainable params: 557
# Non-trainable params: 0
# _________________________________________________________________

# %%
nn_model.history.params
# Out:
# {'verbose': 0, 'epochs': 1, 'steps': 2}

# %%
for layer in nn_model.layers:
    print(layer.get_weights())
# Out:
# []
# [array([[ 0.16494852,  0.24792442, -0.09224575, -0.05056995, -0.0045878 ,
#          0.10948324,  0.0120917 ,  0.27936542,  0.01182813, -0.11795676],
#        [-0.15962397, -0.14365122,  0.07616007, -0.00302594,  0.04901929,
#          0.10510337,  0.17127125, -0.23947135,  0.00337417,  0.0789002 ],
#        [-0.01720083, -0.00673715, -0.0182681 ,  0.0124847 ,  0.00616812,
#         -0.02176634, -0.04308333,  0.06007554, -0.09273223,  0.00122827],
#        [-0.05256962,  0.23564285,  0.08512368,  0.04378041, -0.05533222,
#          0.1146119 , -0.02889767,  0.2138471 , -0.04440343, -0.13200568],
#        [ 0.20301645,  0.10730275, -0.23100303,  0.07787145, -0.19571604,
#          0.23443003, -0.18988883, -0.05509493,  0.12221855, -0.02895913],
#        [-0.02440904,  0.06921812,  0.10689207,  0.16579981, -0.02706663,
#          0.14296155,  0.00992554, -0.07444988, -0.10826118, -0.01532305],
#        [-0.14359038,  0.07184446,  0.02359809,  0.11111907,  0.00914728,
#          0.17789252, -0.00433847,  0.14466412, -0.09657861, -0.04974403],
#        [ 0.23670177,  0.16517615, -0.03860339,  0.08643597,  0.00615034,
#         -0.12744701,  0.02317759,  0.0492373 ,  0.16119556,  0.10492285],
#        [ 0.02514308, -0.11880364,  0.08579367, -0.06067681, -0.06703744,
#         -0.0244323 , -0.00933736, -0.13726777, -0.00815232,  0.0817703 ],
#        [ 0.22073995, -0.24860649, -0.04064435,  0.03676348, -0.08016296,
#          0.05899652,  0.13055335, -0.22619121,  0.04533053, -0.00295688],
#        [ 0.08056685,  0.17405833,  0.00479727, -0.17659523, -0.07299577,
#          0.16383255, -0.0047272 ,  0.27188036, -0.0688125 , -0.0447351 ],
#        [-0.00157716,  0.03322006,  0.13906048,  0.05676884,  0.08762656,
#          0.09761838, -0.0022759 ,  0.03304116, -0.08230975, -0.00691173],
#        [ 0.16694066, -0.00581113, -0.07926136, -0.04441516, -0.00940013,
#          0.04010864,  0.10191174,  0.17727599, -0.00220836, -0.03922316],
#        [ 0.11449962, -0.01942932, -0.09866439, -0.20290002, -0.15766105,
#          0.133389  ,  0.04306009, -0.17112373, -0.03664636, -0.14833252],
#        [ 0.02421972,  0.16642806,  0.03118584, -0.04911884,  0.08417842,
#          0.00836651,  0.01645094, -0.0971999 , -0.07966208, -0.06219893],
#        [-0.03237754,  0.12088085, -0.0772725 ,  0.1884169 ,  0.09570199,
#         -0.2204458 ,  0.14982983, -0.03355553, -0.22770552,  0.10524884],
#        [ 0.17207488,  0.15750964, -0.05330914, -0.21885252, -0.02105227,
#          0.13724159, -0.06523722,  0.36392233,  0.02833005,  0.0424769 ],
#        [ 0.02392601, -0.12328811, -0.00710699, -0.1315147 , -0.03212574,
#          0.05825714, -0.01963394,  0.08044725, -0.04226243,  0.10760395],
#        [ 0.08263321,  0.1683331 ,  0.06047905, -0.1019791 ,  0.06220588,
#          0.11697166, -0.02824702, -0.2450878 , -0.29795477, -0.12403811],
#        [-0.06107143,  0.28689465, -0.11526684, -0.2513729 , -0.01836606,
#         -0.1236565 , -0.09225791,  0.2857602 , -0.00843559, -0.05797624],
#        [ 0.03067428,  0.06810192, -0.01523698,  0.1126528 , -0.00121633,
#          0.08761694,  0.02116828,  0.19627817, -0.07692691, -0.07764154],
#        [ 0.18309012,  0.06459555,  0.16219951,  0.23918323, -0.18452512,
#          0.15705688, -0.11110447,  0.17745845, -0.0445146 ,  0.078068  ],
#        [ 0.00097866, -0.04061045, -0.10021325, -0.04514043, -0.0277039 ,
#          0.11427791,  0.03916606, -0.09309109,  0.13616933, -0.00741736],
#        [ 0.03962446, -0.17696865,  0.07952042, -0.11329237, -0.00580305,
#          0.16050154, -0.0483401 ,  0.08124281,  0.02773194,  0.0517088 ],
#        [ 0.21226485, -0.0481772 , -0.01187304,  0.02802434, -0.08885255,
#          0.19697031, -0.12129039, -0.21797565, -0.14817   ,  0.03573215],
#        [-0.00740944,  0.12976246, -0.07011642,  0.13371828, -0.17076029,
#          0.09941012,  0.13268934, -0.05801481,  0.01827613, -0.15278035],
#        [ 0.07068135,  0.11714014,  0.04920433, -0.03500617,  0.00656834,
#          0.10912786, -0.03207621, -0.05014966, -0.02064216,  0.03202872],
#        [ 0.17988077, -0.12689303, -0.13470295,  0.16630192, -0.16751747,
#          0.19269092, -0.02334515,  0.05478291,  0.01827501, -0.15580568],
#        [ 0.09556774,  0.15733446,  0.15440567,  0.15746531, -0.09102294,
#          0.11959293,  0.00970457, -0.15722552,  0.13431491, -0.06036275],
#        [-0.00900423, -0.06256477, -0.02522147,  0.01774419, -0.00963592,
#          0.01910798,  0.01660426,  0.01514672, -0.00776042, -0.00543953],
#        [ 0.17851944,  0.04243927, -0.06264007,  0.14990139, -0.0030934 ,
#         -0.08623565, -0.11336114,  0.14180464, -0.03471699,  0.13915351],
#        [ 0.04202   , -0.19243811,  0.06118453, -0.03066905, -0.02799156,
#          0.16368175,  0.20964466, -0.10999597,  0.17633024,  0.02316832],
#        [-0.0734726 ,  0.21193543,  0.09034202, -0.09705524,  0.0006417 ,
#          0.03510863, -0.10009675, -0.0277981 , -0.0080254 , -0.07974362],
#        [-0.34646812, -0.33344808,  0.03086377,  0.35234275, -0.19924302,
#          0.24271159,  0.16728327, -0.17964767, -0.06187339, -0.1322882 ],
#        [ 0.01615222,  0.4189244 ,  0.10049267, -0.05916576,  0.16169837,
#          0.05780366,  0.01693436, -0.05785972,  0.03744685,  0.09085105],
#        [-0.02990355, -0.00527837, -0.02410975, -0.00207095,  0.01322498,
#          0.01535645,  0.00639126,  0.04968181, -0.03545452, -0.03091246],
#        [-0.02384748,  0.24416067,  0.00512444, -0.10210381, -0.14480059,
#          0.16221544,  0.18858033,  0.1337275 , -0.11279597, -0.14139606],
#        [-0.09836642,  0.14449355, -0.00977238, -0.05663326,  0.00677681,
#          0.14972599, -0.09827077,  0.1551228 , -0.08944864,  0.07819345],
#        [ 0.02918867,  0.11918887, -0.02244458,  0.01581759, -0.03019529,
#          0.03348419,  0.01224805,  0.00991998, -0.0673323 , -0.00612482],
#        [ 0.08984452, -0.01450006,  0.00657685,  0.09926759, -0.11994464,
#          0.060449  , -0.00947561,  0.22261177,  0.19645402, -0.18754168],
#        [ 0.15828924,  0.22058813,  0.17537211,  0.08673175, -0.11289284,
#         -0.06150173,  0.0976997 , -0.08652117, -0.10890376, -0.12867236],
#        [-0.07925114, -0.00325446,  0.027071  , -0.19225079, -0.01292043,
#          0.10871815, -0.09026156,  0.14977808, -0.00755356, -0.06008013],
#        [ 0.31022537,  0.3664873 , -0.05406104,  0.02369135, -0.11991715,
#         -0.26413748, -0.06515541,  0.05992232, -0.13426925, -0.08984848],
#        [ 0.04623843, -0.26337442, -0.17192142,  0.21569738, -0.01051995,
#          0.0804632 ,  0.2663478 ,  0.19629318, -0.16681553,  0.12942179],
#        [-0.01327289,  0.02947058, -0.05730584,  0.05045563,  0.06832469,
#          0.15521856, -0.00723944, -0.11728704, -0.03342143, -0.05346535],
#        [-0.11168568, -0.08740924, -0.18787277, -0.12127564, -0.06222384,
#         -0.20172237,  0.14758375,  0.1842129 ,  0.10176115, -0.02248227],
#        [ 0.11406346,  0.29773206, -0.07508258,  0.1373517 , -0.08092047,
#          0.13185677, -0.18394712, -0.15703714,  0.1955826 , -0.07047397],
#        [-0.09510858,  0.06710162,  0.0280188 , -0.11323638, -0.02426941,
#          0.13613275,  0.0532058 , -0.05382727, -0.0893999 ,  0.10054563]],
#       dtype=float32), array([ 0.10401411,  0.03800183, -0.05110106,  0.02999198, -0.05732827,
#         0.08354642, -0.00844899,  0.01583832, -0.04306712, -0.05951522],
#       dtype=float32)]
# [array([[ 0.09774279,  0.04674107,  0.4223947 ,  0.4754349 ,  0.18680975],
#        [-0.73944026,  0.08858235, -0.00556871,  0.7261432 , -0.09843732],
#        [-0.2097617 ,  0.18850192, -0.21416873, -0.00244034, -0.03977541],
#        [ 0.26431996, -0.28884003, -0.47340694,  0.03324359,  0.0595199 ],
#        [-0.4111105 , -0.35556978, -0.21726586,  0.01564055, -0.41455814],
#        [ 0.44940066,  0.10743281,  0.5677903 , -0.20135649,  0.3880041 ],
#        [ 0.15887015,  0.23435403, -0.58456683,  0.18315321, -0.13688843],
#        [-0.303883  ,  0.62022877,  0.17720547,  0.11855493, -0.40033776],
#        [-0.49507594, -0.3409587 , -0.01279989, -0.14873637,  0.07361431],
#        [-0.32638994, -0.10899143, -0.43502402, -0.07028539, -0.33544108]],
#       dtype=float32), array([0.05883617, 0.00407181, 0.03574245, 0.01993929, 0.02357811],
#       dtype=float32)]
# [array([[ 1.0761355 , -0.92769617],
#        [-0.821851  , -0.04878278],
#        [-0.5422613 ,  0.6082776 ],
#        [-0.41862226,  0.2851667 ],
#        [ 0.6549011 , -0.36696905]], dtype=float32), array([-0.00424331,  0.00424331], dtype=float32)]
